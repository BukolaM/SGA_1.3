# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /private/var/folders/73/dfnlcqg57w7btn76pt1r17cm0000gp/T/pip-req-build-m172inv8
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /private/var/folders/73/dfnlcqg57w7btn76pt1r17cm0000gp/T/pip-req-build-m172inv8
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit cbdaee6864aa8d3e9e4326d4fe224a517aabbc2c
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools
from datetime import datetime

# %%
#Importing the datetime to calculate the time for scraping the 200000 tweets
start_time = datetime.now()

loc = '9.0820, 8.6753, 923768km'
Ng = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'geocode:"{}" since:2022-12-15 until:2022-12-16'.format(loc)).get_items(), 15000))

end_time = datetime.now()

Ng
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:16:15.514817

# %%
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)
pd.set_option('display.max_colwidth', None)

# %%
Ng
# Out:
#                                                                url  \
# 0          https://twitter.com/_calmguy/status/1603540406276333568
# 1      https://twitter.com/NemoAugustus/status/1603540405215453184
# 2      https://twitter.com/am_BinHamzat/status/1603540402170101763
# 3        https://twitter.com/olami_de01/status/1603540400773423104
# 4      https://twitter.com/Gospelbuzzng/status/1603540400526041088
# ...                                                            ...
# 14995   https://twitter.com/KingPasifik/status/1603527642958860288
# 14996     https://twitter.com/BeebsWrld/status/1603527642770202633
# 14997     https://twitter.com/kayyblaqq/status/1603527641612619776
# 14998   https://twitter.com/otunbadibby/status/1603527640920604675
# 14999      https://twitter.com/oyekitch/status/1603527640639496195
#
#                            date  \
# 0     2022-12-15 23:59:59+00:00
# 1     2022-12-15 23:59:59+00:00
# 2     2022-12-15 23:59:58+00:00
# ...

# %%
Ng.to_csv('sentiment14.csv')
