# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://www.livescores.com/football/england/premier-league/?tz=1"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'lxml')

# %%
table = soup.find('table')
table
# Out:
# <table class="Ke Le"><thead class="Oe"><tr data-testid="league_table_tab-Premier_League"><th class="Pe">#</th><th class="Qe">Team name</th><th class="Se" id="leagueTable-p">P<span class="Te">Played</span></th><th class="Se" id="leagueTable-w">W<span class="Te">Wins</span></th><th class="Se" id="leagueTable-d">D<span class="Te">Draws</span></th><th class="Se" id="leagueTable-l">L<span class="Te">Losses</span></th><th class="Se" id="leagueTable-f">F<span class="Te">Goals For</span></th><th class="Se" id="leagueTable-a">A<span class="Te">Goals Against</span></th><th class="Se" id="leagueTable-gd">GD<span class="Te">Goals Difference</span></th><th class="Se" id="leagueTable-pts">Pts<span class="Te">Points</span></th></tr></thead><tbody><tr class="ze xe" data-testid="league_row-2773"><td class="Jj dark-blue Kj"><span class="Ij">1</span><span class="Lj">Champions League</span></td><td class="Be" data-testid="league_row_name-2773">Arsenal</td><td class="Ce" data-testid="league_row_colum-played_2773">14</td><td class="Ce" data-testid="league_row_colum-wins_2773">12</td><td class="Ce" data-testid="league_row_colum-draws_2773">1</td><td class="Ce" data-testid="league_row_colum-losses_2773">1</td><td class="Ce" data-testid="league_row_colum-goalsFor_2773">33</td><td class="Ce" data-testid="league_row_colum-goalsAgainst_2773">11</td><td class="Ce" data-testid="league_row_colum-goalsDiff_2773">22</td><td class="Ce" data-testid="league_row_colum-points_2773">37</td></tr><tr class="xe" data-testid="league_row-12633"><td class="Jj dark-blue Kj"><span class="Ij">2</span><span class="Lj">Champions League</span></td><td class="Be" data-testid="league_row_name-12633">Manchester City</td><td class="Ce" data-testid="league_row_colum-played_12633">14</td><td class="Ce" data-testid="league_row_colum-wins_12633">10</td><td class="Ce" data-testid="league_row_colum-draws_12633">2</td><td class="Ce" data-testid="league_row_colum-losses_12633">2</td><td class="Ce" data-testid="league_row_colum-goalsFor_12633">40</td><td class="Ce" data-testid="league_row_colum-goalsAgainst_12633">14</td><td class="Ce" data-testid="league_row_colum-goalsDiff_12633">26</td><td class="Ce" data-testid="league_row_colum-points_12633">32</td></tr><tr class="ze xe" data-testid="league_row-2986"><td class="Jj dark-blue Kj"><span class="Ij">3</span><span class="Lj">Champions League</span></td><td class="Be" data-testid="league_row_name-2986">Newcastle United</td><td class="Ce" data-testid="league_row_colum-played_2986">15</td><td class="Ce" data-testid="league_row_colum-wins_2986">8</td><td class="Ce" data-testid="league_row_colum-draws_2986">6</td><td class="Ce" data-testid="league_row_colum-losses_2986">1</td><td class="Ce" data-testid="league_row_colum-goalsFor_2986">29</td><td class="Ce" data-testid="league_row_colum-goalsAgainst_2986">11</td><td class="Ce" data-testid="league_row_colum-goalsDiff_2986">18</td><td class="Ce" data-testid="league_row_colum-points_2986">30</td></tr><tr class="xe" data-testid="league_row-3339"><td class="Jj dark-blue Kj"><span class="Ij">4</span><span class="Lj">Champions League</span></td><td class="Be" data-testid="league_row_name-3339">Tottenham Hotspur</td><td class="Ce" data-testid="league_row_colum-played_3339">15</td><td class="Ce" data-testid="league_row_colum-wins_3339">9</td><td class="Ce" data-testid="league_row_colum-draws_3339">2</td><td class="Ce" data-testid="league_row_colum-losses_3339">4</td><td class="Ce" data-testid="league_row_colum-goalsFor_3339">31</td><td class="Ce" data-testid="league_row_colum-goalsAgainst_3339">21</td><td class="Ce" data-testid="league_row_colum-goalsDiff_3339">10</td><td class="Ce" data-testid="league_row_colum-points_3339">29</td></tr><tr class="ze xe" data-testid="league_row-2810"><td class="Jj medium-orange Kj"><span class="Ij">5</span><span class="Lj">Europa League</span></td><td class="Be" data-testid="league_row_name-2810">Manchester United</td><td class="Ce" data-testid="league_row_colum-played_28 ...

# %%
headers = [header.text for header in table.select('thead tr th')]

results = [{headers[i]: cell.text for i, cell in enumerate(row.findAll("td"))} for row in table.select("tbody tr")]
headers
# Out:
# ['#',
#  'Team name',
#  'PPlayed',
#  'WWins',
#  'DDraws',
#  'LLosses',
#  'FGoals For',
#  'AGoals Against',
#  'GDGoals Difference',
#  'PtsPoints']

# %%
df = pd.DataFrame(results)
df
# Out:
#                     #                Team name PPlayed WWins DDraws LLosses  \
# 0   1Champions League                  Arsenal      14    12      1       1
# 1   2Champions League          Manchester City      14    10      2       2
# 2   3Champions League         Newcastle United      15     8      6       1
# 3   4Champions League        Tottenham Hotspur      15     9      2       4
# 4      5Europa League        Manchester United      14     8      2       4
# 5                   6                Liverpool      14     6      4       4
# 6                   7   Brighton & Hove Albion      14     6      3       5
# 7                   8                  Chelsea      14     6      3       5
# 8                   9                   Fulham      15     5      4       6
# 9                  10                Brentford      15     4      7       4
# 10                 11           Crystal Palace      14     5      4       5
# 11                 12              Aston Villa      15     5      3       7
# 12                 13           Leicester City      15     5      2       8
# 13                 14          AFC Bournemouth      15     4      4       7
# 14                 15             Leeds United      14     4      3       7
# 15                 16          West Ham United      15     4      2       9
# 16                 17                  Everton      15     3      5       7
# 17       18Relegation        Nottingham Forest      15     3      4       8
# 18       19Relegation              Southampton      15     3      3       9
# 19       20Relegation  Wolverhampton Wanderers      15     2      4       9
#
#    FGoals For AGoals Against GDGoals Difference PtsPoints
# 0          33             11                 22        37
# 1          40             14                 26        32
# 2          29             11                 18        30
# 3          31             21                 10        29
# 4          20             20                  0        26
# 5          28             17                 11        22
# 6          23             19                  4        21
# 7          17             17                  0        21
# 8          24             26                 -2        19
# 9          23             25                 -2        19
# 10         15             18                 -3        19
# 11         16             22                 -6        18
# 12         25             25                  0        17
# 13         18             32                -14        16
# 14         22             26                 -4        15
# 15         12             17                 -5        14
# 16         11             17                 -6        14
# 17         11             30                -19        13
# 18         13             27                -14        12
# 19          8             24                -16        10
