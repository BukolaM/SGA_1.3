# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from warnings import simplefilter 
simplefilter(action='ignore', category=DeprecationWarning)

# %%
#view the dataset
df = pd.read_csv('WorldCupMatches.csv')
df.head(2)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
#
#                   Referee               Assistant 1            Assistant 2  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)    REGO Gilberto (BRA)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)  WARNKEN Alberto (CHI)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 0    201.0   1096.0                FRA                MEX
# 1    201.0   1090.0                USA                BEL

# %%
#data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    float64
#  17  MatchID               852 non-null    float64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(8), object(12)
# memory usage: 714.5+ KB

# %%
#the shape of the dataset
df.shape
# Out:
# (4572, 20)

# %%
#the full description of the datasset
df.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# min                0.000000              0.000000  2.010000e+02  2.500000e+01
# 25%                0.000000              0.000000  2.620000e+02  1.188750e+03
# 50%                0.000000              0.000000  3.370000e+02  2.191000e+03
# 75%                1.000000              1.000000  2.497220e+05  4.395006e+07
# max                6.000000              5.000000  9.741060e+07  3.001865e+08

# %%
#finding out the the types of data in each column
df.dtypes
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %% [markdown]
# ## Making a Copy of The Dataset
# I would be working with this copy through out the project while the original dataframe would be for referencing when needed

# %%
#making a copy of my dataset
df_matches = df.copy()

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# #### Issue 1: Renaming Columns
# This is to achieve uniformity

# %%
df_matches = df_matches.rename(columns = {'Year':'year', 'Datetime':'datetime','Stage':'stage','Stadium':'stadium', 
                                         'City':'city','Home Team Name':'home_team_name','Home Team Goals':'home_team_goals',
                                        'Away Team Goals':'away_team_goals', 'Away Team Name':'away_team_name',
                                        'Win conditions':'win_conditions', 'Attendance':'attendance',
                                         'Half-time Home Goals':'half-time_home_goals', 'Half-time Away Goals':'half-time_away_goals',
                                         'Referee':'referee', 'Assistant 1':'assistant_1',
                                         'Assistant 2':'assistant_2','RoundID':'roundID',
                                         'MatchID':'matchID', 'Home Team Initials':'home_team_initials',
                                         'Away Team Initials':'away_team_initials'})

# %% [markdown]
# #### Issue 2: Dropping rows with all NaN values

# %%
df_matches = df_matches.dropna(axis=0)

# %% [markdown]
# #### Issue 3: Normalizing the datetime so as to extract the months and date for further analysis

# %%
df_matches['datetime'] = pd.to_datetime(df_matches.datetime).dt.strftime('%Y-%m-%d')
df_matches['datetime'] = pd.to_datetime(df_matches['datetime'])
df_matches['month'] = pd.to_datetime(df_matches.datetime).dt.month
df_matches['day'] = pd.to_datetime(df_matches.datetime).dt.day

# %% [markdown]
# #### Issue 4: `year`, `month` and `day`

# %%
#confirmining if there are any null values
df_matches[['year', 'month', 'day']].isnull().sum()
# Out:
# year     0
# month    0
# day      0
# dtype: int64

# %%
#convert to int datatype
df_matches[['year', 'month', 'day']] = df_matches[['year', 'month', 'day']].astype(int)

# %% [markdown]
# #### Issue 5: 	`home_team_goals`, `away_team_goals`, `half-time_away_goals`, `roundID`	and `matchID`

# %%
#confirmining if there are any null values
df_matches[['home_team_goals', 'away_team_goals', 'half-time_away_goals', 'roundID', 'matchID']].isnull().sum()
# Out:
# home_team_goals         0
# away_team_goals         0
# half-time_away_goals    0
# roundID                 0
# matchID                 0
# dtype: int64

# %%
#convert to int datatype
df_matches[
['home_team_goals', 'away_team_goals', 
'half-time_away_goals', 'roundID', 'matchID']] = df_matches[
['home_team_goals', 'away_team_goals', 
'half-time_away_goals', 'roundID', 'matchID']].astype(int)

# %% [markdown]
# #### Issue 6: Replace `win_conditions` Blank values with NaN to None

# %%
#replace empty values with NaN values
df_matches['win_conditions'] = df_matches['win_conditions'].replace(r'^\s*$', np.nan, regex=True) 
df_matches['win_conditions']
# Out:
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#                        ...
# 847    Netherlands win on penalties (4 - 3)
# 848                                      NaN
# 849      Argentina win on penalties (2 - 4)
# 850                                      NaN
# 851            Germany win after extra time
# Name: win_conditions, Length: 850, dtype: object

# %%
df_matches['win_conditions'] = df_matches['win_conditions'].fillna('None')

# %%
df_matches
# Out:
#      year   datetime                     stage              stadium  \
# 0    1930 1930-07-13                   Group 1              Pocitos
# 1    1930 1930-07-13                   Group 4       Parque Central
# 2    1930 1930-07-14                   Group 2       Parque Central
# 3    1930 1930-07-14                   Group 3              Pocitos
# 4    1930 1930-07-15                   Group 1       Parque Central
# ..    ...        ...                       ...                  ...
# 847  2014 2014-07-05            Quarter-finals     Arena Fonte Nova
# 848  2014 2014-07-08               Semi-finals     Estadio Mineirao
# 849  2014 2014-07-09               Semi-finals   Arena de Sao Paulo
# 850  2014 2014-07-12  Play-off for third place     Estadio Nacional
# 851  2014 2014-07-13                     Final  Estadio do Maracana
#
#                 city home_team_name  home_team_goals  away_team_goals  \
# 0        Montevideo          France                4                1
# 1        Montevideo             USA                3                0
# 2        Montevideo      Yugoslavia                2                1
# 3        Montevideo         Romania                3                1
# 4        Montevideo       Argentina                1                0
# ..               ...            ...              ...              ...
# 847        Salvador     Netherlands                0                0
# 848  Belo Horizonte          Brazil                1                7
# 849       Sao Paulo     Netherlands                0                0
# 850        Brasilia          Brazil                0                3
# 851  Rio De Janeiro         Germany                1                0
#
#     away_team_name                         win_conditions  ...  \
# 0           Mexico                                   None  ...
# 1          Belgium                                   None  ...
# 2           Brazil                                   None  ...
# 3             Peru                                   None  ...
# 4           France                                   None  ...
# ..             ...                                    ...  ...
# 847     Costa Rica  Netherlands win on penalties (4 - 3)   ...
# 848        Germany                                   None  ...
# 849      Argentina    Argentina win on penalties (2 - 4)   ...
# 850    Netherlands                                   None  ...
# 851      Argentina          Germany win after extra time   ...
#
#      half-time_away_goals                 referee  \
# 0                       0  LOMBARDI Domingo (URU)
# 1                       0       MACIAS Jose (ARG)
# 2                       0     TEJADA Anibal (URU)
# 3                       0   WARNKEN Alberto (CHI)
# 4                       0     REGO Gilberto (BRA)
# ..                    ...                     ...
# 847                     0   Ravshan IRMATOV (UZB)
# 848                     5   RODRIGUEZ Marco (MEX)
# 849                     0      C�neyt �AKIR (TUR)
# 850                     2   HAIMOUDI Djamel (ALG)
# 851                     0    Nicola RIZZOLI (ITA)
#
#                      assistant_1                 assistant_2 roundID  \
# 0          CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)     201
# 1       MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)     201
# 2        VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)     201
# 3            LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)     201
# 4           SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)     201
# ..                           ...                         ...     ...
# 847  RASULOV Abduxamidullo (UZB)    KOCHKAROV Bakhadyr (KGZ)  255953
# 848      TORRENTERA Marvin (MEX)       QUINTERO Marcos (MEX)  255955
# 849         DURAN Bahattin (TUR)           ONGUN Tarik (TUR)  255955
# 850         ACHIK Redouane (MAR)     ETCHIALI Abdelhak (ALG)  255957
# 851        Renato FAVERANI (ITA)        Andrea STEFANI (ITA)  255959
#
#        matchID  home_team_initials  away_team_initials month day
# 0         1096                 FRA                 MEX     7  13
# 1         1090                 USA                 BEL     7  13
# 2         1093                 YUG                 BRA     7  14
# 3         1098                 ROU                 PER     7  14
# 4         1085                 ARG                 FRA     7  15
# ..         ...                 ...                 ...   ...  ..
# 847  300186488                 NED                 CRC     7   5
# 848  300186474                 BRA                 GER     7   8
# 849  300186490                 NED                 ARG     7   9
# 850  300186502                 BRA                 NED     7  12
# 851  300186501                 GER                 ARG     7  13
#
# [850 rows x 22 columns]

# %% [markdown]
# ## Exporting the Cleaned Data to a New csv

# %%
#export the data to a new csv file
df1_matches = df_matches.to_csv('WorldCupMatches_clean.csv', index = False)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_Matches = pd.read_csv('WorldCupMatches_clean.csv')
df_Matches
# Out:
#      year    datetime                     stage              stadium  \
# 0    1930  1930-07-13                   Group 1              Pocitos
# 1    1930  1930-07-13                   Group 4       Parque Central
# 2    1930  1930-07-14                   Group 2       Parque Central
# 3    1930  1930-07-14                   Group 3              Pocitos
# 4    1930  1930-07-15                   Group 1       Parque Central
# ..    ...         ...                       ...                  ...
# 845  2014  2014-07-05            Quarter-finals     Arena Fonte Nova
# 846  2014  2014-07-08               Semi-finals     Estadio Mineirao
# 847  2014  2014-07-09               Semi-finals   Arena de Sao Paulo
# 848  2014  2014-07-12  Play-off for third place     Estadio Nacional
# 849  2014  2014-07-13                     Final  Estadio do Maracana
#
#                 city home_team_name  home_team_goals  away_team_goals  \
# 0        Montevideo          France                4                1
# 1        Montevideo             USA                3                0
# 2        Montevideo      Yugoslavia                2                1
# 3        Montevideo         Romania                3                1
# 4        Montevideo       Argentina                1                0
# ..               ...            ...              ...              ...
# 845        Salvador     Netherlands                0                0
# 846  Belo Horizonte          Brazil                1                7
# 847       Sao Paulo     Netherlands                0                0
# 848        Brasilia          Brazil                0                3
# 849  Rio De Janeiro         Germany                1                0
#
#     away_team_name                         win_conditions  ...  \
# 0           Mexico                                   None  ...
# 1          Belgium                                   None  ...
# 2           Brazil                                   None  ...
# 3             Peru                                   None  ...
# 4           France                                   None  ...
# ..             ...                                    ...  ...
# 845     Costa Rica  Netherlands win on penalties (4 - 3)   ...
# 846        Germany                                   None  ...
# 847      Argentina    Argentina win on penalties (2 - 4)   ...
# 848    Netherlands                                   None  ...
# 849      Argentina          Germany win after extra time   ...
#
#      half-time_away_goals                 referee  \
# 0                       0  LOMBARDI Domingo (URU)
# 1                       0       MACIAS Jose (ARG)
# 2                       0     TEJADA Anibal (URU)
# 3                       0   WARNKEN Alberto (CHI)
# 4                       0     REGO Gilberto (BRA)
# ..                    ...                     ...
# 845                     0   Ravshan IRMATOV (UZB)
# 846                     5   RODRIGUEZ Marco (MEX)
# 847                     0      C�neyt �AKIR (TUR)
# 848                     2   HAIMOUDI Djamel (ALG)
# 849                     0    Nicola RIZZOLI (ITA)
#
#                      assistant_1                 assistant_2 roundID  \
# 0          CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)     201
# 1       MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)     201
# 2        VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)     201
# 3            LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)     201
# 4           SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)     201
# ..                           ...                         ...     ...
# 845  RASULOV Abduxamidullo (UZB)    KOCHKAROV Bakhadyr (KGZ)  255953
# 846      TORRENTERA Marvin (MEX)       QUINTERO Marcos (MEX)  255955
# 847         DURAN Bahattin (TUR)           ONGUN Tarik (TUR)  255955
# 848         ACHIK Redouane (MAR)     ETCHIALI Abdelhak (ALG)  255957
# 849        Renato FAVERANI (ITA)        Andrea STEFANI (ITA)  255959
#
#        matchID  home_team_initials  away_team_initials month day
# 0         1096                 FRA                 MEX     7  13
# 1         1090                 USA                 BEL     7  13
# 2         1093                 YUG                 BRA     7  14
# 3         1098                 ROU                 PER     7  14
# 4         1085                 ARG                 FRA     7  15
# ..         ...                 ...                 ...   ...  ..
# 845  300186488                 NED                 CRC     7   5
# 846  300186474                 BRA                 GER     7   8
# 847  300186490                 NED                 ARG     7   9
# 848  300186502                 BRA                 NED     7  12
# 849  300186501                 GER                 ARG     7  13
#
# [850 rows x 22 columns]

# %% [markdown]
# #### <span style='color: blue'> Question 1. The data in WorldCupMatches.csv has the goals scored in each match broken up by goals for the home team and goals for the away team. Visualize the total number of goals scored in each match. Create a new column in df named Total Goals, and set it equal to the sum of the columns Home Team Goals and Away Team Goals. Print the results of df.head() to confirm your new column

# %%
#creating a new column total goals
df_Matches['total_goals'] = df_Matches['home_team_goals'] + df_Matches['away_team_goals']
df_Matches.head()
# Out:
#    year    datetime    stage         stadium         city home_team_name  \
# 0  1930  1930-07-13  Group 1         Pocitos  Montevideo          France
# 1  1930  1930-07-13  Group 4  Parque Central  Montevideo             USA
# 2  1930  1930-07-14  Group 2  Parque Central  Montevideo      Yugoslavia
# 3  1930  1930-07-14  Group 3         Pocitos  Montevideo         Romania
# 4  1930  1930-07-15  Group 1  Parque Central  Montevideo       Argentina
#
#    home_team_goals  away_team_goals away_team_name win_conditions  ...  \
# 0                4                1         Mexico           None  ...
# 1                3                0        Belgium           None  ...
# 2                2                1         Brazil           None  ...
# 3                3                1           Peru           None  ...
# 4                1                0         France           None  ...
#
#                   referee               assistant_1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   assistant_2 roundID matchID home_team_initials  \
# 0         REGO Gilberto (BRA)     201    1096                FRA
# 1       WARNKEN Alberto (CHI)     201    1090                USA
# 2         BALWAY Thomas (FRA)     201    1093                YUG
# 3    MATEUCCI Francisco (URU)     201    1098                ROU
# 4  RADULESCU Constantin (ROU)     201    1085                ARG
#
#    away_team_initials  month day total_goals
# 0                 MEX      7  13           5
# 1                 BEL      7  13           3
# 2                 BRA      7  14           3
# 3                 PER      7  14           4
# 4                 FRA      7  15           1
#
# [5 rows x 23 columns]

# %% [markdown]
# #### <span style='color: blue'> Question 2. Create a bar chart visualizing how many goals were scored each year the World Cup was held between 1930-2014.  Set the style of your plot to be whitegrid . This will add gridlines to the plot which will make it easier to read the visualization.

# %%
#grouping the goals based on the year to get their total sum
df_Matches1 = df_Matches.groupby(['year'])['total_goals'].sum().reset_index(
            name='total_goals').sort_values(['year'])
df_Matches1
# Out:
#     year  total_goals
# 0   1930           70
# 1   1934           70
# 2   1938           84
# 3   1950           88
# 4   1954          140
# 5   1958          126
# 6   1962           89
# 7   1966           89
# 8   1970           95
# 9   1974           97
# 10  1978          102
# 11  1982          146
# 12  1986          132
# 13  1990          115
# 14  1994          141
# 15  1998          171
# 16  2002          161
# 17  2006          147
# 18  2010          145
# 19  2014          200

# %%
# plotting the results using a bar chart
fig, ax = plt.subplots(figsize=(12,7),  sharex=True)
sns.set_style("whitegrid")
ax = sns.barplot(x = 'year', y = 'total_goals', data = df_Matches1, palette = 'winter_r')
ax.set_title('total goals scored in each year', fontsize= 15)
plt.show()

# %% [markdown]
# #### <span style='color: blue'> Question 3. Create a box plot so you can visualize the distribution of the average goals for each year with a bar chart.

# %%
# plotting the results using a box plot
fig, ax = plt.subplots( figsize=(20,6),  sharex=True)
sns.set_style("darkgrid")
ax = sns.boxplot(x = 'year', y = 'total_goals', data = df_Matches,  palette='Spectral')
ax.set_title('goals scored in each year', fontsize= 20)
plt.show()
