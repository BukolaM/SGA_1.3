# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Question 1: Generate a KDE plot for the size feature of the tips dataset

# %%
fig = plt.figure(figsize=(8,6))
sns.kdeplot(data=tips, x = tips['size'], shade=True, color='blue') 
plt.legend(['size'])
plt.title('KDE plot for the size', fontsize= 12)
plt.show()

# %% [markdown]
# - From the chart above, most of the tips are between the range of 2 and 3.

# %% [markdown]
# ### Question 2 :Using the boxplots, generate the distribution of total bill by gender for the tips dataset. Give detailed explanations of your observations

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(x = 'sex', y = 'total_bill', data=tips, palette='PuRd')
plt.xlabel('sex', fontsize= 10)
plt.ylabel('total_bill', fontsize= 10)
plt.title('distribution of total bill by gender ', fontsize= 15)
plt.show()

# %% [markdown]
# - The box  above shows the quartiles of the total bill by gender while the whiskers extend to show the rest of the distribution, except for points that are determined to be `outliers`.
# - We can also see that the median amount/bill spent by male and female diners is almost the same.

# %% [markdown]
# ### Question 3: Using boxplots generate the distribution of tips by days. Give detailed explanations of your observations

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(x = 'day', y = 'total_bill', data=tips, palette='RdYlGn')
plt.xlabel('day', fontsize= 10)
plt.ylabel('total_bill', fontsize= 10)
plt.title('distribution of tips by days', fontsize= 15)
plt.show()

# %% [markdown]
# - The box above shows the quartiles of the total bill by day while the whiskers extend to show the rest of the distribution, except for points that are determined to be outliers.
# -  The total bill amounts per day shows that the amount spent increases at the weekend and is lowest on a Friday.

# %% [markdown]
# ### Question 4: Using boxplots generate the distribution of total bill by days considering smoker status of the customer. Give detailed explanation of your observations

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(x = 'day', y = 'total_bill', hue= 'smoker', data=tips, palette='PiYG')
plt.xlabel('day', fontsize= 10)
plt.ylabel('total_bill', fontsize= 10)
plt.title('distribution of tips by days', fontsize= 15)
plt.show()

# %% [markdown]
# - From the chart above, Thursday seems to be the only day when the median bills for smokers and non-smokers are almost similar.

# %% [markdown]
# ### Question 5: Using violin plots generate the distribution of total bill by time given the genders. Give detailed explanations of your observations.

# %%
fig = plt.figure(figsize=(8,6))
sns.violinplot(y='time', x='total_bill', hue="sex", data=tips, palette='muted')
plt.xlabel('total_bill', fontsize= 10)
plt.ylabel('time', fontsize= 10)
plt.title('distribution of total bill by time given the genders', fontsize= 15)
plt.show()

# %% [markdown]
# - There is a huge difference in the minimum and maximum amounts spent. Men are more likely to pay for food during dates or when out with a larger group of people, which might be why the most expensive bills are under their name.

# %% [markdown]
# ### Question 6: Using violin plots generate the distribution of tips by days also considering time. Give detailed explanations of your observations.

# %%
fig = plt.figure(figsize=(8,7))
sns.violinplot(x='tip', y='day', hue = 'time', data=tips, palette='magma')
plt.xlabel('tip', fontsize= 10)
plt.ylabel('time', fontsize= 10)
plt.title(' the distribution of tips by days also considering time', fontsize= 15)
plt.show()

# %% [markdown]
# - From the chart above, it can be seen that saturdays are the busiest day of the week which automatically gives the highest tip day however,  only dinners were served.
# - Sundays were again very busy but also had only dinner served.

# %% [markdown]
# ### Question 7: Plot and customize a correlations heatmap for the tips dataset.

# %%
fig = plt.figure(figsize=(8,8))
sns.heatmap(tips.corr(),linecolor='white', annot= True, linewidths = 2)
plt.title('correlations heatmap for the tips', fontsize= 12)
plt.show()

# %% [markdown]
# - The heatmap shows that the positive linear relationship observed between total bill and tip (0.68) is slightly higher than the positive relationship between total bill and size(0.6) while the relationship between size and tip is very low although it is positive as well(0.49).
